# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn.externals import joblib
import numpy as np
rhino_root = '/'

df_fr3 = pd.read_csv('FR3_all_amp_2019-12-20.csv').iloc[:,1:]
df_fr5 = pd.read_csv('FR5_all_amp_2019-12-20.csv').iloc[:,1:]

# %%
df = pd.concat([df_fr3,df_fr5])  # combine two experiments
df['label'] = 'Encoding_LTC'
df['is_LTC'] = True

# %%
grouped = df.groupby(['session', 'subject', 'label', 'experiment']) # group by session, subject, label, exp


# for name, group in grouped:
#     print(name)
#     print(np.mean(group['recalled']))

def p_summary(x):
    # return pd.DataFrame({'all':np.mean(x['recalled']), 'stim':np.mean(x['recalled'][x['is_stim_list']]), 'no_stim': np.mean(x['recalled'][~x['is_stim_list']])})
    return np.mean(x['recalled'])


df_all = grouped.apply(p_summary).reset_index()
df_stim = grouped.apply((lambda x: np.mean(x[x['is_stim_list'] == 1]['recalled']))).reset_index()
df_no_stim = grouped.apply((lambda x: np.mean(x[x['is_stim_list'] != 1]['recalled']))).reset_index()
# Out:
# (0, 'R1374T', 'catFR5')
# 0.19318181818181818
# (0, 'R1379E', 'catFR5')
# 0.24242424242424243
# (0, 'R1465D', 'catFR5')
# 0.5454545454545454
# (0, 'R1487T', 'catFR5')
# 0.07575757575757576
# (0, 'R1488T', 'catFR5')
# 0.2159090909090909
# (0, 'R1491T', 'catFR5')
# 0.01893939393939394
# (1, 'R1487T', 'catFR5')
# 0.08712121212121213
# (2, 'R1374T', 'catFR5')
# 0.16666666666666666
# (2, 'R1489E', 'catFR5')
# 0.4583333333333333
# (3, 'R1489E', 'catFR5')
# 0.5113636363636364

# %%
# Out:
#      serialpos session subject experiment         mstime  type recalled list  \
# 0            1       0  R1374T     catFR5  1513119065621  WORD        1    4
# 1            2       0  R1374T     catFR5  1513119068046  WORD        1    4
# 2            3       0  R1374T     catFR5  1513119070438  WORD        0    4
# 3            4       0  R1374T     catFR5  1513119072839  WORD        0    4
# 4            5       0  R1374T     catFR5  1513119075327  WORD        0    4
# ...        ...     ...     ...        ...            ...   ...      ...  ...
# 2635         8       0  R1491T     catFR5  1568216352746  WORD        0   25
# 2636         9       0  R1491T     catFR5  1568216355455  WORD        0   25
# 2637        10       0  R1491T     catFR5  1568216357937  WORD        0   25
# 2638        11       0  R1491T     catFR5  1568216360521  WORD        0   25
# 2639        12       0  R1491T     catFR5  1568216363087  WORD        0   25
#
#      is_stim_list phase  ... thresh classifier_output             location  \
# 0               1  STIM  ...    0.5          0.936618  Left middletemporal
# 1               1  STIM  ...    0.5          0.604470  Left middletemporal
# 2               1  STIM  ...    0.5          0.188381  Left middletemporal
# 3               1  STIM  ...    0.5          0.617498  Left middletemporal
# 4               1  STIM  ...    0.5          0.606337  Left middletemporal
# ...           ...   ...  ...    ...               ...                  ...
# 2635            1  STIM  ...    0.5          0.615224                  NaN
# 2636            1  STIM  ...    0.5          0.381860                  NaN
# 2637            1  STIM  ...    0.5          0.551543                  NaN
# 2638            1  STIM  ...    0.5          0.450223                  NaN
# 2639            1  STIM  ...    0.5          0.613534                  NaN
#
#       amplitude  pulse_freq stim_duration  stimAnodeTag  stimCathodeTag  \
# 0           0.5       200.0         500.0           LA7             LA8
# 1           0.5       200.0         500.0           LA7             LA8
# 2           0.5       200.0         500.0           LA7             LA8
# 3           0.5       200.0         500.0           LA7             LA8
# 4           0.5       200.0         500.0           LA7             LA8
# ...         ...         ...           ...           ...             ...
# 2635        NaN         NaN           NaN           NaN             NaN
# 2636        NaN         NaN           NaN           NaN             NaN
# 2637        NaN         NaN           NaN           NaN             NaN
# 2638        NaN         NaN           NaN           NaN             NaN
# 2639        NaN         NaN           NaN           NaN             NaN
#
#       is_tbi is_LTC
# 0       True   True
# 1       True   True
# 2       True   True
# 3       True   True
# 4       True   True
# ...      ...    ...
# 2635    True   True
# 2636    True   True
# 2637    True   True
# 2638    True   True
# 2639    True   True
#
# [2640 rows x 23 columns]
